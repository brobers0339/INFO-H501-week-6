# %% [markdown]
# <font color='darkred'> Unless otherwise noted, **this notebook will not be reviewed or autograded.**</font> You are welcome to use it for scratchwork, but **only the files listed in the exercises will be checked.**
#
# ---
#
# # Exercises
#
# For these exercises, you'll be creating a [Python class](https://www.hackerearth.com/practice/python/object-oriented-programming/classes-and-objects-i/tutorial/) in the *apputil.py* file.
#
# A few tips:
#
# - Some of these exercises will require some "JSON digging".
# - <font color='lightblue'>Your functions should still adhere to [best practices](https://codesignal.com/learn/courses/clean-code-basics-with-python/lessons/clean-function-design-in-python), so **your class should probably contain more functions than only the ones dictated below**.</font>

# %% [markdown]
# ## Exercise 1
#
# Create a Python class named `Genius` such that the following code initializes the object, and "saves" the access token as an attribute of the object. You'll need to use this attribute for Exercises 2 and 3.
#
# ```python
# from apputil import Genius
#
# genius = Genius(access_token="access_token")
# ```

# %%
# %load_ext autoreload

# %%
from apputil import Genius

genius = Genius(access_token='access_token')
print(genius.access_token)
# Out:
# access_token

# %% [markdown]
# ## Exercise 2
#
# Reference the `json_data` in the lab. Notice, when we search for an artist name (e.g., "Missy Elliot") in Genius, the result is a list of *songs* attributed to that artist. Suppose we want to capture information about the artist themselves.
#
# Create a method for our `Genius` class called `.get_artist(search_term)` which does the following:
#
# 1. Extract the (most likely, "Primary") Artist ID from the first "hit" of the `search_term`.
# 2. Use the [API path](https://docs.genius.com/#artists-h2) for this Artist ID to pull information about the artist.
# 3. **Return** the dictionary containing the resulting JSON object.
#
# For example, the following code should return a dictionary of artist information:
#
# ```python
# genius.get_artist("Radiohead")
# ```

# %%
from apputil import Genius

genius = Genius(access_token='HqGMeY2Yvsgz-85yDBBwCwwXpglCEtjzwolY9W4JLL3uRFTicN4rqKyy0zEUSKag')

# %%
genius.get_artist("Rihanna")
# Out:
# {'meta': {'status': 200},
#  'response': {'artist': {'alternate_names': ['Robyn Fenty',
#     'Robyn Rihanna Fenty',
#     'R. Fenty',
#     'Bad Girl Riri',
#     'Robyn R. Fenty'],
#    'api_path': '/artists/89',
#    'description': {'dom': {'tag': 'root',
#      'children': [{'tag': 'p',
#        'children': ['A true pop icon, Robyn “Rihanna” Fenty is a singer, actress, and businesswoman from Saint Michael, Barbados. She was first discovered by American record producer ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/artists/Evan-rogers',
#           'rel': 'noopener'},
#          'data': {'api_path': '/artists/71734'},
#          'children': ['Evan Rogers']},
#         ' in 2003 and later signed a contract to Def Jam Recordings in 2004, after auditioning for its then-president, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/artists/Jay-z',
#           'rel': 'noopener'},
#          'data': {'api_path': '/artists/2'},
#          'children': ['JAY-Z']},
#         '.']},
#       '',
#       {'tag': 'p',
#        'children': ['The following year, in 2005, she released her debut album ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/albums/Rihanna/Music-of-the-sun',
#           'rel': 'noopener'},
#          'data': {'api_path': '/albums/34318'},
#          'children': [{'tag': 'em', 'children': ['Music of the Sun']}]},
#         ' and its follow-up, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/albums/Rihanna/A-girl-like-me',
#           'rel': 'noopener'},
#          'data': {'api_path': '/albums/342628'},
#          'children': [{'tag': 'em', 'children': ['A Girl Like Me']}]},
#         ', in 2006. Both albums did well commercially, but it wasn’t until the release of her third album, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/albums/Rihanna/Good-girl-gone-bad',
#           'rel': 'noopener'},
#          'data': {'api_path': '/albums/6513'},
#          'children': [{'tag': 'em', 'children': ['Good Girl Gone Bad']}]},
#         ', in 2007 that poised Rihanna as an international pop star. It became her first album to receive a Grammy nomination (seven to be exact) and features one of her biggest hits, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Rihanna-umbrella-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/1629'},
#          'children': ['“Umbrella.”']}]},
#       '',
#       {'tag': 'p',
#        'children': ['Moving onto 2009, Rihanna released her fourth studio album, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/albums/Rihanna/Rated-r',
#           'rel': 'noopener'},
#          'data': {'api_path': '/albums/10909'},
#          'children': [{'tag': 'em', 'children': ['Rated R']}]},
#         '. It featured a darker and more atmospheric tone from her previous albums. She released her fifth studio album, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/albums/Rihanna/Loud',
#           'rel': 'noopener'},
#          'data': {'api_path': '/albums/6336'},
#          'children': [{'tag': 'em', 'children': ['Loud']}]},
#         ', the next year in 2010. It marked her return to making dance-pop records. That summer, she featured on ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/artists/Eminem',
#           'rel': 'noopener'},
#          'data': {'api_path': '/artists/45'},
#          'children': ['Eminem']},
#         '’s smash hit, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Eminem-love-the-way-you-lie-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/532'},
#          'children': ['“Love the Way You Lie”']},
#         ' and is one of her most popular features of all time.']},
#       '',
#       {'tag': 'p',
#        'children': ['Rihanna continued her album streak in 2011 when she released her sixth studio album, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/albums/Rihanna/Talk-that-talk',
#           'rel': 'noopener'},
#          'data': {'api_path': '/albums/13121'},
#          'children': [{'tag': 'em', 'children': ['Talk That Talk']}]},
#         '. It’s lead-single, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Rihanna-we-found-love-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/56642'},
#          'children': ['“We Found Love,”']},
#         ' became her biggest hit to date, topping the ',
#         {'tag': 'em', 'children': ['Billboard']},
#         ' Hot 100 for ten weeks. The next year, in 2012, she released her seventh studio album, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/albums/Rihanna/Unapologetic',
#           'rel': 'noopener'},
#          'data': {'api_path': '/albums/23824'},
#          'children': [{'tag': 'em', 'children': ['Unapologetic']}]},
#         '.']},
#       '',
#       {'tag': 'p',
#        'children': ['2013 ended Rihanna’s three-year album streak, taking a short break from recording music. Instead, she featured on songs like ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/artists/Wale',
#           'rel': 'noopener'},
#          'data': {'api_path': '/artists/396'},
#          'children': ['Wale']},
#         '’s ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Wale-bad-remix-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/160737'},
#          'children': ['“Bad (Remix)”']},
#         ' and Eminem’s ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Eminem-the-monster-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/235732'},
#          'children': ['“The Monster.”']},
#         ' The following year, in 2014, Rihanna left Def Jam Recordings to sign fully with JAY-Z’s Roc Nation.']},
#       '',
#       {'tag': 'p',
#        'children': ['2015 saw Rihanna’s return to making solo music, releasing singles like ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Rihanna-kanye-west-and-paul-mccartney-fourfiveseconds-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/690706'},
#          'children': ['“FourFiveSeconds,”']},
#         ' ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Rihanna-bitch-better-have-my-money-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/731783'},
#          'children': ['“Bitch Better Have My Money”']},
#         ' and ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Rihanna-american-oxygen-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/718028'},
#          'children': ['“American Oxygen.”']},
#         ' The following year, in 2016, she released her eighth studio album ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/albums/Rihanna/Anti',
#           'rel': 'noopener'},
#          'data': {'api_path': '/albums/132689'},
#          'children': [{'tag': 'em', 'children': ['ANTI']}]},
#         '.']},
#       '',
#       {'tag': 'p',
#        'children': ['In 2017, Rihanna featured on a few hit songs like ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/artists/Kendrick-lamar',
#           'rel': 'noopener'},
#          'data': {'api_path': '/artists/1421'},
#          'children': ['Kendrick Lamar']},
#         '’s ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Kendrick-lamar-loyalty-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/3047135'},
#          'children': ['“LOYALTY.”']},
#         ' and ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/artists/Dj-khaled',
#           'rel': 'noopener'},
#          'data': {'api_path': '/artists/158'},
#          'children': ['DJ Khaled']},
#         '’s ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Dj-khaled-wild-thoughts-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/3114474'},
#          'children': ['“Wild Thoughts.”']},
#         ' That same year, she announced she began working on her ninth studio album, although a proper release date has yet to be announced.']},
#       '',
#       {'tag': 'p',
#        'children': ['With all her hard work, Rihanna has ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://en.wikipedia.org/wiki/List_of_awards_and_nominations_received_by_Rihanna',
#           'rel': 'noopener nofollow'},
#          'children': ['become one of the most awarded artists']},
#         ' in history, winning 214 in total. Of these awards include nine Grammy Awards, twelve ',
#         {'tag': 'em', 'children': ['Billboard']},
#         ' Music Awards, thirteen American Music Awards, and seven ',
#         {'tag': 'em', 'children': ['MTV']},
#         ' Video Music Awards.']},
#       '',
#       {'tag': 'p',
#        'children': ['Aside from music, Rihanna has ventured into other affairs like acting, starring in big movies like ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://www.imdb.com/title/tt5164214/',
#           'rel': 'noopener nofollow'},
#          'children': [{'tag': 'em', 'children': ['Ocean’s 8']}]},
#         ', ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://www.imdb.com/title/tt1245492/',
#           'rel': 'noopener nofollow'},
#          'children': [{'tag': 'em', 'children': ['This Is the End']}]},
#         ', ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://www.imdb.com/title/tt1440129/',
#           'rel': 'noopener nofollow'},
#          'children': [{'tag': 'em', 'children': ['Battleship']}]},
#         ', and the animated cartoon, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://www.imdb.com/title/tt2224026/',
#           'rel': 'noopener nofollow'},
#          'children': [{'tag': 'em', 'children': ['Home']}]},
#         '. Rih also launched the highly successful cosmetics brand, ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/artists/Fety-beauty',
#           'rel': 'noopener'},
#          'data': {'api_path': '/artists/3912310'},
#          'children': ['Fenty Beauty']},
#         ', in 2017 and was also ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://www.bbc.com/news/world-latin-america-45609656',
#           'rel': 'noopener nofollow'},
#          'children': ['appointed']},
#         ' as an Ambassador of Barbados in 2018.']}]}},
#    'facebook_name': 'Rihanna',
#    'header_image_url': 'https://images.genius.com/7fbc0f95ca9d7d24853328749c8affd1.1000x333x1.jpg',
#    'id': 89,
#    'image_url': 'https://images.genius.com/ccba37ee9940591cf24eab7e18efcf66.1000x1000x1.png',
#    'instagram_name': 'badgalriri',
#    'is_meme_verified': True,
#    'is_verified': True,
#    'name': 'Rihanna',
#    'translation_artist': False,
#    'twitter_name': 'Rihanna',
#    'url': 'https://genius.com/artists/Rihanna',
#    'current_user_metadata': {'permissions': ['view_activity_stream',
#      'view_discography'],
#     'excluded_permissions': ['edit',
#      'edit_images',
#      'edit_names',
#      'edit_anything',
#      'merge',
#      'sort_artist_songs',
#      'follow',
#      'view_contribution_opportunities',
#      'edit_translation_artist',
#      'split',
#      'see_short_id'],
#     'interactions': {'following': False}},
#    'followers_count': 5809,
#    'iq': 2323,
#    'description_annotation': {'_type': 'referent',
#     'annotator_id': 2,
#     'annotator_login': 'hellrel',
#     'api_path': '/referents/6925696',
#     'classification': 'accepted',
#     'fragment': 'Rihanna',
#     'id': 6925696,
#     'is_description': True,
#     'path': '/6925696/Rihanna/Rihanna',
#     'range': {'content': 'Rihanna'},
#     'song_id': None,
#     'url': 'https://genius.com/6925696/Rihanna/Rihanna',
#     'verified_annotator_ids': [],
#     'annotatable': {'api_path': '/artists/89',
#      'context': None,
#      'id': 89,
#      'image_url': 'https://images.genius.com/ccba37ee9940591cf24eab7e18efcf66.1000x1000x1.png',
#      'link_title': 'Rihanna',
#      'title': 'Rihanna',
#      'type': 'Artist',
#      'url': 'https://genius.com/artists/Rihanna'},
#     'annotations': [{'api_path': '/annotations/6925696',
#       'body': {'dom': {'tag': 'root',
#         'children': [{'tag': 'p',
#           'children': ['A true pop icon, Robyn “Rihanna” Fenty is a singer, actress, and businesswoman from Saint Michael, Barbados. She was first discovered by American record producer ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/artists/Evan-rogers',
#              'rel': 'noopener'},
#             'data': {'api_path': '/artists/71734'},
#             'children': ['Evan Rogers']},
#            ' in 2003 and later signed a contract to Def Jam Recordings in 2004, after auditioning for its then-president, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/artists/Jay-z',
#              'rel': 'noopener'},
#             'data': {'api_path': '/artists/2'},
#             'children': ['JAY-Z']},
#            '.']},
#          '',
#          {'tag': 'p',
#           'children': ['The following year, in 2005, she released her debut album ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/albums/Rihanna/Music-of-the-sun',
#              'rel': 'noopener'},
#             'data': {'api_path': '/albums/34318'},
#             'children': [{'tag': 'em', 'children': ['Music of the Sun']}]},
#            ' and its follow-up, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/albums/Rihanna/A-girl-like-me',
#              'rel': 'noopener'},
#             'data': {'api_path': '/albums/342628'},
#             'children': [{'tag': 'em', 'children': ['A Girl Like Me']}]},
#            ', in 2006. Both albums did well commercially, but it wasn’t until the release of her third album, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/albums/Rihanna/Good-girl-gone-bad',
#              'rel': 'noopener'},
#             'data': {'api_path': '/albums/6513'},
#             'children': [{'tag': 'em', 'children': ['Good Girl Gone Bad']}]},
#            ', in 2007 that poised Rihanna as an international pop star. It became her first album to receive a Grammy nomination (seven to be exact) and features one of her biggest hits, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Rihanna-umbrella-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/1629'},
#             'children': ['“Umbrella.”']}]},
#          '',
#          {'tag': 'p',
#           'children': ['Moving onto 2009, Rihanna released her fourth studio album, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/albums/Rihanna/Rated-r',
#              'rel': 'noopener'},
#             'data': {'api_path': '/albums/10909'},
#             'children': [{'tag': 'em', 'children': ['Rated R']}]},
#            '. It featured a darker and more atmospheric tone from her previous albums. She released her fifth studio album, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/albums/Rihanna/Loud',
#              'rel': 'noopener'},
#             'data': {'api_path': '/albums/6336'},
#             'children': [{'tag': 'em', 'children': ['Loud']}]},
#            ', the next year in 2010. It marked her return to making dance-pop records. That summer, she featured on ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/artists/Eminem',
#              'rel': 'noopener'},
#             'data': {'api_path': '/artists/45'},
#             'children': ['Eminem']},
#            '’s smash hit, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Eminem-love-the-way-you-lie-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/532'},
#             'children': ['“Love the Way You Lie”']},
#            ' and is one of her most popular features of all time.']},
#          '',
#          {'tag': 'p',
#           'children': ['Rihanna continued her album streak in 2011 when she released her sixth studio album, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/albums/Rihanna/Talk-that-talk',
#              'rel': 'noopener'},
#             'data': {'api_path': '/albums/13121'},
#             'children': [{'tag': 'em', 'children': ['Talk That Talk']}]},
#            '. It’s lead-single, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Rihanna-we-found-love-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/56642'},
#             'children': ['“We Found Love,”']},
#            ' became her biggest hit to date, topping the ',
#            {'tag': 'em', 'children': ['Billboard']},
#            ' Hot 100 for ten weeks. The next year, in 2012, she released her seventh studio album, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/albums/Rihanna/Unapologetic',
#              'rel': 'noopener'},
#             'data': {'api_path': '/albums/23824'},
#             'children': [{'tag': 'em', 'children': ['Unapologetic']}]},
#            '.']},
#          '',
#          {'tag': 'p',
#           'children': ['2013 ended Rihanna’s three-year album streak, taking a short break from recording music. Instead, she featured on songs like ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/artists/Wale',
#              'rel': 'noopener'},
#             'data': {'api_path': '/artists/396'},
#             'children': ['Wale']},
#            '’s ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Wale-bad-remix-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/160737'},
#             'children': ['“Bad (Remix)”']},
#            ' and Eminem’s ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Eminem-the-monster-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/235732'},
#             'children': ['“The Monster.”']},
#            ' The following year, in 2014, Rihanna left Def Jam Recordings to sign fully with JAY-Z’s Roc Nation.']},
#          '',
#          {'tag': 'p',
#           'children': ['2015 saw Rihanna’s return to making solo music, releasing singles like ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Rihanna-kanye-west-and-paul-mccartney-fourfiveseconds-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/690706'},
#             'children': ['“FourFiveSeconds,”']},
#            ' ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Rihanna-bitch-better-have-my-money-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/731783'},
#             'children': ['“Bitch Better Have My Money”']},
#            ' and ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Rihanna-american-oxygen-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/718028'},
#             'children': ['“American Oxygen.”']},
#            ' The following year, in 2016, she released her eighth studio album ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/albums/Rihanna/Anti',
#              'rel': 'noopener'},
#             'data': {'api_path': '/albums/132689'},
#             'children': [{'tag': 'em', 'children': ['ANTI']}]},
#            '.']},
#          '',
#          {'tag': 'p',
#           'children': ['In 2017, Rihanna featured on a few hit songs like ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/artists/Kendrick-lamar',
#              'rel': 'noopener'},
#             'data': {'api_path': '/artists/1421'},
#             'children': ['Kendrick Lamar']},
#            '’s ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Kendrick-lamar-loyalty-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/3047135'},
#             'children': ['“LOYALTY.”']},
#            ' and ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/artists/Dj-khaled',
#              'rel': 'noopener'},
#             'data': {'api_path': '/artists/158'},
#             'children': ['DJ Khaled']},
#            '’s ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Dj-khaled-wild-thoughts-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/3114474'},
#             'children': ['“Wild Thoughts.”']},
#            ' That same year, she announced she began working on her ninth studio album, although a proper release date has yet to be announced.']},
#          '',
#          {'tag': 'p',
#           'children': ['With all her hard work, Rihanna has ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://en.wikipedia.org/wiki/List_of_awards_and_nominations_received_by_Rihanna',
#              'rel': 'noopener nofollow'},
#             'children': ['become one of the most awarded artists']},
#            ' in history, winning 214 in total. Of these awards include nine Grammy Awards, twelve ',
#            {'tag': 'em', 'children': ['Billboard']},
#            ' Music Awards, thirteen American Music Awards, and seven ',
#            {'tag': 'em', 'children': ['MTV']},
#            ' Video Music Awards.']},
#          '',
#          {'tag': 'p',
#           'children': ['Aside from music, Rihanna has ventured into other affairs like acting, starring in big movies like ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://www.imdb.com/title/tt5164214/',
#              'rel': 'noopener nofollow'},
#             'children': [{'tag': 'em', 'children': ['Ocean’s 8']}]},
#            ', ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://www.imdb.com/title/tt1245492/',
#              'rel': 'noopener nofollow'},
#             'children': [{'tag': 'em', 'children': ['This Is the End']}]},
#            ', ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://www.imdb.com/title/tt1440129/',
#              'rel': 'noopener nofollow'},
#             'children': [{'tag': 'em', 'children': ['Battleship']}]},
#            ', and the animated cartoon, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://www.imdb.com/title/tt2224026/',
#              'rel': 'noopener nofollow'},
#             'children': [{'tag': 'em', 'children': ['Home']}]},
#            '. Rih also launched the highly successful cosmetics brand, ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/artists/Fety-beauty',
#              'rel': 'noopener'},
#             'data': {'api_path': '/artists/3912310'},
#             'children': ['Fenty Beauty']},
#            ', in 2017 and was also ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://www.bbc.com/news/world-latin-america-45609656',
#              'rel': 'noopener nofollow'},
#             'children': ['appointed']},
#            ' as an Ambassador of Barbados in 2018.']}]}},
#       'comment_count': 1,
#       'community': True,
#       'custom_preview': None,
#       'has_voters': True,
#       'id': 6925696,
#       'pinned': False,
#       'share_url': 'https://genius.com/6925696',
#       'source': None,
#       'state': 'accepted',
#       'url': 'https://genius.com/6925696/Rihanna/Rihanna',
#       'verified': False,
#       'votes_total': 364,
#       'current_user_metadata': {'permissions': [],
#        'excluded_permissions': ['vote',
#         'edit',
#         'cosign',
#         'uncosign',
#         'destroy',
#         'accept',
#         'reject',
#         'see_unreviewed',
#         'clear_votes',
#         'propose_edit_to',
#         'pin_to_profile',
#         'unpin_from_profile',
#         'update_source',
#         'edit_custom_preview',
#         'report_as_abusive',
#         'create_comment'],
#        'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#        'iq_by_action': {}},
#       'authors': [{'attribution': 0.8616071428571429,
#         'pinned_role': None,
#         'user': {'api_path': '/users/4335922',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/19235db3955f307e1b767a599e1e1715',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/19235db3955f307e1b767a599e1e1715',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/19235db3955f307e1b767a599e1e1715',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/19235db3955f307e1b767a599e1e1715',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.genius.com/avatars/medium/19235db3955f307e1b767a599e1e1715',
#          'human_readable_role_for_display': 'Moderator',
#          'id': 4335922,
#          'iq': 1052194,
#          'login': 'Chancelorr',
#          'name': '\u200bchancelorr',
#          'role_for_display': 'moderator',
#          'url': 'https://genius.com/Chancelorr',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.049107142857142856,
#         'pinned_role': None,
#         'user': {'api_path': '/users/332956',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/a7fe234bc419283a036dd9f892531e53',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/a7fe234bc419283a036dd9f892531e53',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/a7fe234bc419283a036dd9f892531e53',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/a7fe234bc419283a036dd9f892531e53',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.genius.com/avatars/medium/a7fe234bc419283a036dd9f892531e53',
#          'human_readable_role_for_display': 'Editor',
#          'id': 332956,
#          'iq': 143630,
#          'login': 'Wsu',
#          'name': 'Wsu',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/Wsu',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.029017857142857144,
#         'pinned_role': None,
#         'user': {'api_path': '/users/2',
#          'avatar': {'tiny': {'url': 'https://assets.genius.com/images/default_avatar_16.png?1762287909',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://assets.genius.com/images/default_avatar_32.png?1762287909',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://assets.genius.com/images/default_avatar_100.png?1762287909',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://assets.genius.com/images/default_avatar_300.png?1762287909',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1762287909',
#          'human_readable_role_for_display': 'Editor',
#          'id': 2,
#          'iq': 135887,
#          'login': 'hellrel',
#          'name': 'hellrel',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/hellrel',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.024553571428571428,
#         'pinned_role': None,
#         'user': {'api_path': '/users/1448826',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/744bc3b7bd77206b4c768fadc9911a25',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/744bc3b7bd77206b4c768fadc9911a25',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/744bc3b7bd77206b4c768fadc9911a25',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/744bc3b7bd77206b4c768fadc9911a25',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.genius.com/427478c68f285fc5e038b6995aabbbb9.600x600x1.png',
#          'human_readable_role_for_display': 'Moderator',
#          'id': 1448826,
#          'iq': 207210,
#          'login': 'babuc',
#          'name': 'Babu Chatterjee',
#          'role_for_display': 'moderator',
#          'url': 'https://genius.com/babuc',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.015625,
#         'pinned_role': None,
#         'user': {'api_path': '/users/1090559',
#          'avatar': {'tiny': {'url': 'https://assets.genius.com/images/default_avatar_16.png?1762287909',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://assets.genius.com/images/default_avatar_32.png?1762287909',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://assets.genius.com/images/default_avatar_100.png?1762287909',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://assets.genius.com/images/default_avatar_300.png?1762287909',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1762287909',
#          'human_readable_role_for_display': None,
#          'id': 1090559,
#          'iq': 42,
#          'login': 'neemiller',
#          'name': 'neemiller',
#          'role_for_display': None,
#          'url': 'https://genius.com/neemiller',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.004464285714285715,
#         'pinned_role': None,
#         'user': {'api_path': '/users/993805',
#          'avatar': {'tiny': {'url': 'https://filepicker-images.genius.com/ruar8gm48qe',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://filepicker-images.genius.com/ruar8gm48qe',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://filepicker-images.genius.com/ruar8gm48qe',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://filepicker-images.genius.com/ruar8gm48qe',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://filepicker-images.genius.com/73c9ellj2f7',
#          'human_readable_role_for_display': 'Contributor',
#          'id': 993805,
#          'iq': 84976,
#          'login': 'StayInTheHouse',
#          'name': 'StayInTheHouse',
#          'role_for_display': 'contributor',
#          'url': 'https://genius.com/StayInTheHouse',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.004464285714285715,
#         'pinned_role': None,
#         'user': {'api_path': '/users/179147',
#          'avatar': {'tiny': {'url': 'https://filepicker-images.genius.com/j3o75ww98l8',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://filepicker-images.genius.com/j3o75ww98l8',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://filepicker-images.genius.com/j3o75ww98l8',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://filepicker-images.genius.com/j3o75ww98l8',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://filepicker-images.genius.com/rb12zcrbjw',
#          'human_readable_role_for_display': 'Contributor',
#          'id': 179147,
#          'iq': 3823,
#          'login': 'staIIi',
#          'name': 'staIIi',
#          'role_for_display': 'contributor',
#          'url': 'https://genius.com/staIIi',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.004464285714285715,
#         'pinned_role': None,
#         'user': {'api_path': '/users/1931244',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/3655b7947c455ad9378be8cd9dc63f62',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/3655b7947c455ad9378be8cd9dc63f62',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/3655b7947c455ad9378be8cd9dc63f62',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/3655b7947c455ad9378be8cd9dc63f62',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.genius.com/f45814fd26ee32464af77c72e7e0e3d0.1000x750x1.jpg',
#          'human_readable_role_for_display': 'Editor',
#          'id': 1931244,
#          'iq': 354346,
#          'login': 'eatthemooncake',
#          'name': '\u200beatthemooncake',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/eatthemooncake',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.0022321428571428575,
#         'pinned_role': None,
#         'user': {'api_path': '/users/1007856',
#          'avatar': {'tiny': {'url': 'https://images.rapgenius.com/avatars/tiny/632c3847e73c0af1ac4537226db52ff0',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.rapgenius.com/avatars/thumb/632c3847e73c0af1ac4537226db52ff0',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.rapgenius.com/avatars/small/632c3847e73c0af1ac4537226db52ff0',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.rapgenius.com/avatars/medium/632c3847e73c0af1ac4537226db52ff0',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.rapgenius.com/avatars/medium/632c3847e73c0af1ac4537226db52ff0',
#          'human_readable_role_for_display': 'Editor',
#          'id': 1007856,
#          'iq': 37655,
#          'login': 'OnlyEverArabella',
#          'name': 'OnlyEverArabella',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/OnlyEverArabella',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.0022321428571428575,
#         'pinned_role': None,
#         'user': {'api_path': '/users/8315100',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/f4dc1da1ccb558f844f078eb9cd0ff5d',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/f4dc1da1ccb558f844f078eb9cd0ff5d',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/f4dc1da1ccb558f844f078eb9cd0ff5d',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/f4dc1da1ccb558f844f078eb9cd0ff5d',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.genius.com/a60b7740774e4636062895d57d65c4c5.667x1000x1.jpg',
#          'human_readable_role_for_display': 'Editor',
#          'id': 8315100,
#          'iq': 319821,
#          'login': 'glitzy',
#          'name': '\u200bglitzy',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/glitzy',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.0022321428571428575,
#         'pinned_role': None,
#         'user': {'api_path': '/users/16263551',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/b215e63d9311c9240df2440afdbcff8f',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/b215e63d9311c9240df2440afdbcff8f',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/b215e63d9311c9240df2440afdbcff8f',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/b215e63d9311c9240df2440afdbcff8f',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://filepicker-images.genius.com/wnwzw0pq65',
#          'human_readable_role_for_display': None,
#          'id': 16263551,
#          'iq': 106,
#          'login': 'MemoryMakuchete',
#          'name': 'MemoryMakuchete',
#          'role_for_display': None,
#          'url': 'https://genius.com/MemoryMakuchete',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}}],
#       'cosigned_by': [],
#       'rejection_comment': None,
#       'verified_by': None}]},
#    'user': {'api_path': '/users/2784771',
#     'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/6f125cd015e6772353b50079e93c14b6',
#       'bounding_box': {'width': 16, 'height': 16}},
#      'thumb': {'url': 'https://images.genius.com/avatars/thumb/6f125cd015e6772353b50079e93c14b6',
#       'bounding_box': {'width': 32, 'height': 32}},
#      'small': {'url': 'https://images.genius.com/avatars/small/6f125cd015e6772353b50079e93c14b6',
#       'bounding_box': {'width': 100, 'height': 100}},
#      'medium': {'url': 'https://images.genius.com/avatars/medium/6f125cd015e6772353b50079e93c14b6',
#       'bounding_box': {'width': 300, 'height': 400}}},
#     'header_image_url': 'https://images.genius.com/7fbc0f95ca9d7d24853328749c8affd1.1000x333x1.jpg',
#     'human_readable_role_for_display': 'Verified Artist',
#     'id': 2784771,
#     'iq': 2323,
#     'login': 'rihanna',
#     'name': 'Rihanna',
#     'role_for_display': 'verified_artist',
#     'url': 'https://genius.com/rihanna',
#     'current_user_metadata': {'permissions': [],
#      'excluded_permissions': ['follow'],
#      'interactions': {'following': False}}}}}}

# %% [markdown]
# ## Exercise 3
#
# Use the result from Exercise 2 to create another method for our `Genius` class called `.get_artists(search_terms)` (plural) which takes in a *list* of search terms, and returns a DataFrame containing a row for each search term, and the following columns:
#
# - `search_term`: the raw search term from `search_terms`
# - `artist_name`: the (most likely) artist name for the search term
# - `artist_id`: the Genius Artist ID for that artist, based on the API call
# - `followers_count`: the number of followers for that artist (if available)
#
# For example, the following should return a DataFrame with 4 rows:
#
# ```python
# genius.get_artists(['Rihanna', 'Tycho', 'Seal', 'U2'])
# ```

# %%
from apputil import Genius
# %autoreload 2

genius = Genius(access_token='HqGMeY2Yvsgz-85yDBBwCwwXpglCEtjzwolY9W4JLL3uRFTicN4rqKyy0zEUSKag')
genius.get_artists(['Rihanna', 'Tycho', 'Seal', 'U2'])
# Out:
#   search_term   artist_name  artist_id  followers_count
# 0     Rihanna       Rihanna         89             5809
# 1       Tycho         Tycho      53336               30
# 2        Seal  Lil Uzi Vert     217208             6181
# 3          U2            U2      23895              374

# %% [markdown]
# ## Bonus Exercise (optional)
#
# 1. Gather a list of 100+ various musical artists, and save this list in a TXT file.
# 2. Write a Python *script* that saves the result of `.get_artists` for these artists in a CSV file.
# 3. If you have time, adjust this script to use multiprocessing.
